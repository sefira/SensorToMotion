# %%
import pandas as pd
SensorData = pd.read_csv('../data/216_shipeng_lanqiu2.csv')
SizeofData = SensorData.shape

NormalizedSensorData = SensorData.copy()
mean = range(SizeofData[1])
std = range(SizeofData[1])

#normalize the accelerometer and gyroscope data, except the last deviceID
for i in range(SizeofData[1] - 1):
    mean[i] = SensorData.ix[:,i].mean()
    std[i] = SensorData.ix[:,i].std()
    NormalizedSensorData.ix[:,i] -= mean[i]
    NormalizedSensorData.ix[:,i] /= std[i]

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['std', 'mean']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import matplotlib.pyplot as plt

# %%
plot(SensorData['accelerometerX'])
figure()
plot(NormalizedSensorData['accelerometerX'])

# %%
plot(SensorData['accelerometerY'])
figure()
plot(NormalizedSensorData['accelerometerY'])

# %%
plot(SensorData['accelerometerZ'])
figure()
plot(NormalizedSensorData['accelerometerZ'])

# %%
plot(SensorData['gyroscopeX'])
figure()
plot(NormalizedSensorData['gyroscopeX'])

# %%
plot(SensorData['gyroscopeY'])
figure()
plot(NormalizedSensorData['gyroscopeY'])

# %%
plot(SensorData['gyroscopeZ'])
figure()
plot(NormalizedSensorData['gyroscopeZ'])
