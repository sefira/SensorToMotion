# %%
from readData import *

SensorData, NormalizedSensorData = ReadData()

MotionStartTime = [3650,19700,34000,49240,60800,92500,121200]
MotionEndTime = [17650,32000,47100,58000,89200,120400,149000]

StayDribbleSeq = NormalizedSensorData[MotionStartTime[0]-1:MotionEndTime[0]]
RunDribbleSeq = NormalizedSensorData[MotionStartTime[1]-1:MotionEndTime[1]]
WalkSeq = NormalizedSensorData[MotionStartTime[2]-1:MotionEndTime[2]]
RunSeq = NormalizedSensorData[MotionStartTime[3]-1:MotionEndTime[3]]
ShootSeq = NormalizedSensorData[MotionStartTime[4]-1:MotionEndTime[4]]
TestSeq1 = NormalizedSensorData[MotionStartTime[5]-1:MotionEndTime[5]]
TestSeq2 = NormalizedSensorData[MotionStartTime[6]-1:MotionEndTime[6]]

# %%
ShootSeq
# Out:
#        accelerometerX  accelerometerY  accelerometerZ  gyroscopeX  gyroscopeY  \
# 60799        0.021846        0.162073        0.094350    0.086357    0.124557
# 60800        0.022733        0.157724        0.096825    0.078080    0.126955
# 60801        0.022289        0.153809        0.094968    0.077856    0.124157
# 60802        0.024951        0.157289        0.092493    0.083002    0.123757
# 60803        0.020959        0.160333        0.101156    0.086134    0.124357
# 60804        0.019184        0.160768        0.097444    0.086805    0.122958
# 60805        0.016078        0.165987        0.092493    0.087028    0.121759
# 60806        0.020515        0.168597        0.107963    0.086581    0.118561
# 60807        0.025839        0.164248        0.096825    0.086581    0.116563
# 60808        0.027613        0.161203        0.098062    0.087252    0.116563
# 60809        0.025395        0.159898        0.099300    0.093516    0.115164
# ...

# %%
# %matplotlib inline

# %%
plot(ShootSeq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2722b59d7bb2> in <module>()
# ----> 1 plot(ShootSeq)
#
# NameError: name 'plot' is not defined

# %%
plot(ShootSeq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2722b59d7bb2> in <module>()
# ----> 1 plot(ShootSeq)
#
# NameError: name 'plot' is not defined

# %%
import matplotlib

# %%
plot(ShootSeq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2722b59d7bb2> in <module>()
# ----> 1 plot(ShootSeq)
#
# NameError: name 'plot' is not defined

# %%
from matpplotlib import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-08f6f6e9520e> in <module>()
# ----> 1 from matpplotlib import *
#
# ImportError: No module named matpplotlib

# %%
from matplotlib import *

# %%
plot(ShootSeq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2722b59d7bb2> in <module>()
# ----> 1 plot(ShootSeq)
#
# NameError: name 'plot' is not defined

# %%
matplotlib.plot(ShootSeq)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1f921c60b8e6> in <module>()
# ----> 1 matplotlib.plot(ShootSeq)
#
# AttributeError: 'module' object has no attribute 'plot'

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ShootSeq[1000:3000]['accelerometerX'])

# %%
testSeq = ShootSeq[0:500]
plt.plot(testSeq)

# %%
mng = plt.get_current_fig_manager()
mng.frame.Maximize(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f981aeefb736> in <module>()
#       1 mng = plt.get_current_fig_manager()
# ----> 2 mng.frame.Maximize(True)
#
# AttributeError: 'FigureManagerBase' object has no attribute 'frame'

# %%
plt.figure(figsize=(20,10))

# %%
plt.plot(testSeq)

# %%
width = 12
height = 12
plt.figure(figsize=(width, height))

# %%
plt.plot(testSeq)

# %%
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
plt.plot(testSeq)

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 10.0)
plt.plot(testSeq)
